# %% [markdown]
# # Choosing What to Plant.
# ### From the options listed below what should we plant with soil conditions of: N=90, P=42, K=43, temperature=20, humidity=82, ph=6.1, rainfall=202?
# - rice
# - maize
# - chickpea
# - kidneybean
# - pigeonpeas
# - mothbeans
# - mungbean
# - blackgram
# - lentil
# - pomegranate
# - banana
# - mango
# - grapes
# - watermelon
# - muskmelon
# - apple
# - orange
# - papaya
# - coconut
# - cotton
# - jute
# - coffee
# - tea

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Load the dataset
data = pd.read_csv('soil_data.csv')  # Replace with your dataset filename

# Check for missing values
print(data.isnull().sum())
print(data.head())

# Separate features (X) and target (y)
X = data[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
y = data['crop']

# Encode the target variable (convert crop names to numerical labels)
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Standardize the features (optional but recommended for many algorithms)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# crop           0
# dtype: int64
#     N   P   K  temperature   humidity        ph    rainfall  crop
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
# Initialize the model
model = RandomForestClassifier(random_state=42)

# Train the model
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# +# What is a random forest classifier?
# - Random Forest is an ensemble learning method that operates by constructing a multitude of decision trees at training time and outputting the class that is the mode of the classes (classification) or mean prediction (regression) of the individual trees.
# # What is a decision tree?
# (see PPT)

# %% [markdown]
# # From the options what should we plant with soil conditions of: N=90, P=42, K=43, temperature=20, humidity=82, ph=6.1, rainfall=202?

# %%
# Example input for new data
new_data = pd.DataFrame({
    'N': [90],
    'P': [42],
    'K': [43],
    'temperature': [20],
    'humidity': [82],
    'ph': [6.1],
    'rainfall': [202]
})

# Predict the crop
predicted_crop = model.predict(new_data)
print(f"Recommended Crop: {label_encoder.inverse_transform(predicted_crop)[0]}")

# %% [markdown]
# # Can we trust this? How do we know if the model is good?

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# Decode the predicted labels back to crop names
y_pred_crop = label_encoder.inverse_transform(y_pred)
y_test_crop = label_encoder.inverse_transform(y_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9931818181818182

# %%
print("Classification Report:\n", classification_report(y_test_crop, y_pred_crop))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        23
#       banana       1.00      1.00      1.00        21
#    blackgram       1.00      1.00      1.00        20
#     chickpea       1.00      1.00      1.00        26
#      coconut       1.00      1.00      1.00        27
#       coffee       1.00      1.00      1.00        17
#       cotton       1.00      1.00      1.00        17
#       grapes       1.00      1.00      1.00        14
#         jute       0.92      1.00      0.96        23
#  kidneybeans       1.00      1.00      1.00        20
#       lentil       0.92      1.00      0.96        11
#        maize       1.00      1.00      1.00        21
#        mango       1.00      1.00      1.00        19
#    mothbeans       1.00      0.96      0.98        24
#     mungbean       1.00      1.00      1.00        19
#    muskmelon       1.00      1.00      1.00        17
# ...
